# %%
import folium
import os
import base64
from folium import IFrame
import json

# %%
m = folium.Map(location=[16.862935, 74.613319],zoom_start=15)
walkData = os.path.join('path.json')
folium.GeoJson(walkData, name='walk').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tooltip = "Click to see picture"
#html = '<img src="data: ;base64,{}">'.format

#picture1 = base64.b64encode(open('1.png','rb').read()).decode()
#iframe1 = IFrame(html(picture1), width=600+20, height=400+20)
popup1 = folium.Popup(iframe1, max_width=650)
icon1 = folium.Icon(color="red", icon="glyphicon-home")
marker1 = folium.Marker(location=[16.864835, 74.607584], popup=popup1, tooltip=tooltip, icon=icon1).add_to(m)

picture2 = base64.b64encode(open('2.png','rb').read()).decode()
iframe2 = IFrame(html(picture2), width=600+20, height=400+20)
popup2 = folium.Popup(iframe2, max_width=650)
icon2 = folium.features.CustomIcon('2.png', icon_size=(60,60))
marker2 = folium.Marker(location=[16.860939247130045, 74.61632966995238], popup=popup2, tooltip=tooltip, icon=icon2).add_to(m)

picture3 = base64.b64encode(open('3.png','rb').read()).decode()
iframe3 = IFrame(html(picture3), width=400+20, height=600+20)
popup3 = folium.Popup(iframe3, max_width=650)
icon3 = folium.features.CustomIcon('logo2.png', icon_size=(60,60))
marker3 = folium.Marker(location=[16.86808537554144, 74.61652278900146], popup=popup3, tooltip=tooltip, icon=icon3).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
